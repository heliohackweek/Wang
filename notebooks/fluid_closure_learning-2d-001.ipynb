# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
# %matplotlib inline
import sys
import csv
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from numpy import sqrt, cos, sin, pi
from numpy.fft import fft, ifft, rfft, irfft
from tqdm import tqdm
import time
import h5py

print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# ### Generate data

# %%
filename = '../data/data-2d-T2qxxy.001.h5'

# %%
def read_T_q(filename, nsamples=None):
    with h5py.File(filename, 'r') as file:
#         print([k for k in file])
        print('full data shape', file['Txx1'].shape)
        Txx = file['Txx1'][slice(nsamples), ...]
        Txy = file['Txy1'][slice(nsamples), ...]
        q = file['qxxy'][slice(nsamples), ...]
        return Txx, Txy, q
    
def normalize(arr):
    # all data have mean=0
    # XXX use the same max
    return arr / abs(arr).max()

# %%
Txx, Txy, q = read_T_q(filename, 1000)
Txx.shape, q.shape
# Out:
# full data shape (10000, 256, 256)
# ((1000, 256, 256), (1000, 256, 256))

# %%
T = np.empty((1000, 256, 256, 2))
T[..., 0] = Txx
T[..., 1] = Txy

# %%
nsamples, nx, ny = Txx.shape  # FIXME nx, ny order?

# %%
# T = T.reshape((nsamples, nx, ny, 1))
q = q.reshape((nsamples, nx, ny, 1))

# %%
T = normalize(T)
q = normalize(q)

# %%
test_split = 0.05
nsamples_test = int(nsamples * test_split)
nsamples_train = nsamples - nsamples_test

# %%
train_data = T[:nsamples_train, ...]
train_labels = q[:nsamples_train, ...]

test_data = T[nsamples_train:, ...]
test_labels = q[nsamples_train:, ...]

# %% [markdown]
# ### Create the model

# %%
num_filters = 48

# input = keras.Input(shape=train_data.shape[1:])
# layer1 = layers.Conv2D(num_filters, 16, activation='relu', padding='same',
#                        input_shape=train_data.shape[1:])(input),
# layer2 = layers.Dropout(0.5)(layer1)
# layer3 = layers.MaxPool2D(padding='same')(layer2)
# layer4 = layers.Conv2D(num_filters, 16, activation='relu', padding='same')(layer3),
# layer5 = layers.Dropout(0.5)(layer4)
# layer6 = layers.MaxPool2D(padding='same')(layer5)
# layer7 = layers.Conv2D(num_filters, 16, activation='relu', padding='same')(layer6),
# model = layers.Conv2D(1, 1, padding='same', activation='linear')(layer7)

# https://www.machinecurve.com/index.php/2019/12/11/upsampling2d-how-to-use-upsampling-with-keras/#building-your-model-with-keras
model = keras.Sequential([
    layers.Conv2D(num_filters, 16, activation='relu', padding='same', input_shape=train_data.shape[1:]),
    layers.MaxPool2D(padding='same'),
    layers.Conv2D(num_filters, 16, activation='relu', padding='same'),
    layers.MaxPool2D(padding='same'),
    layers.Conv2D(num_filters, 16, activation='relu', padding='same'),
    layers.Conv2D(num_filters, 16, activation='relu', padding='same'),
    layers.UpSampling2D(),
    layers.Conv2D(num_filters, 16, activation='relu', padding='same'),
    layers.UpSampling2D(),
    layers.Conv2D(1, 1, padding='same', activation='linear')
])



model.compile(loss='mse',
              optimizer=keras.optimizers.Adam(lr=1e-4),
              metrics=['accuracy', 'mae', 'mse'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 48)      24624
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 48)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 48)      589872
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 48)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 48)        589872
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 48)        589872
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 128, 128, 48)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 128, 48)      589872
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 256, 256, 48)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 256, 256, 1)       49
# =================================================================
# Total params: 2,384,161
# Trainable params: 2,384,161
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
EPOCHS = 100  # How many times we go through the entire dataset
validation_split = 0.05  # fraction of data to be used as live validation


# https://keras.io/guides/writing_your_own_callbacks/
class PrintLogs(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.time_begin = time.time()

    def on_epoch_end(self, epoch, logs):
        if epoch >0 and (epoch+1) % 1 == 0:
            info = ''
            info += 'EPOCH {}'.format(epoch)
            dt = time.time() - self.time_begin
            dt_per_epoch = dt / (epoch + 1)
            info +='; time total {:g}s per-epoch {:g}s:'.format(dt, dt_per_epoch)
            log_epoch = [
                '{} {:.1e}'.format(key, logs[key]) for key in logs.keys()
            ]
            info += '; '.join(log_epoch)
            print(info)


callbacks = [
#     PrintLogs(),
    keras.callbacks.EarlyStopping(patience=10),
    keras.callbacks.TensorBoard(log_dir="./logs-qxxx")
]

# https://keras.io/api/models/model_training_apis/#fit-method
history = model.fit(train_data,
                    train_labels,
                    epochs=EPOCHS,
                    validation_split=validation_split,
                    verbose=1,
                    callbacks=callbacks,
                   )
# Out:
# Epoch 1/100
#  2/29 [=>............................] - ETA: 1s - loss: 8.0644e-04 - accuracy: 0.0000e+00 - mae: 0.0194 - mse: 8.0644e-04WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0398s vs `on_train_batch_end` time: 0.1073s). Check your callbacks.
# 29/29 [==============================] - 3s 108ms/step - loss: 6.6773e-04 - accuracy: 0.0000e+00 - mae: 0.0170 - mse: 6.6773e-04 - val_loss: 6.9305e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0179 - val_mse: 6.9305e-04
# Epoch 2/100
# 29/29 [==============================] - 3s 105ms/step - loss: 6.3464e-04 - accuracy: 0.0000e+00 - mae: 0.0171 - mse: 6.3464e-04 - val_loss: 5.9494e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0161 - val_mse: 5.9494e-04
# Epoch 3/100
# 29/29 [==============================] - 3s 105ms/step - loss: 5.1290e-04 - accuracy: 0.0000e+00 - mae: 0.0150 - mse: 5.1290e-04 - val_loss: 7.0059e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0197 - val_mse: 7.0059e-04
# Epoch 4/100
# 29/29 [==============================] - 3s 106ms/step - loss: 5.4889e-04 - accuracy: 0.0000e+00 - mae: 0.0163 - mse: 5.4889e-04 - val_loss: 5.0581e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0151 - val_mse: 5.0581e-04
# Epoch 5/100
# 29/29 [==============================] - 3s 105ms/step - loss: 4.3759e-04 - accuracy: 0.0000e+00 - mae: 0.0141 - mse: 4.3759e-04 - val_loss: 4.6959e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0146 - val_mse: 4.6959e-04
# Epoch 6/100
# 29/29 [==============================] - 3s 105ms/step - loss: 4.4295e-04 - accuracy: 0.0000e+00 - mae: 0.0145 - mse: 4.4295e-04 - val_loss: 4.9762e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0157 - val_mse: 4.9762e-04
# Epoch 7/100
# 29/29 [==============================] - 3s 105ms/step - loss: 4.0871e-04 - accuracy: 0.0000e+00 - mae: 0.0139 - mse: 4.0871e-04 - val_loss: 4.0136e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0136 - val_mse: 4.0136e-04
# Epoch 8/100
# 29/29 [==============================] - 3s 105ms/step - loss: 3.7060e-04 - accuracy: 0.0000e+00 - mae: 0.0133 - mse: 3.7060e-04 - val_loss: 3.9562e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0136 - val_mse: 3.9562e-04
# Epoch 9/100
# 29/29 [==============================] - 3s 105ms/step - loss: 3.5332e-04 - accuracy: 0.0000e+00 - mae: 0.0130 - mse: 3.5332e-04 - val_loss: 3.6720e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.
-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0125 - val_mse: 2.8301e-04
# Epoch 61/100
# 29/29 [==============================] - 3s 106ms/step - loss: 1.9923e-04 - accuracy: 0.0000e+00 - mae: 0.0104 - mse: 1.9923e-04 - val_loss: 2.2902e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0108 - val_mse: 2.2902e-04
# Epoch 62/100
# 29/29 [==============================] - 3s 105ms/step - loss: 1.9001e-04 - accuracy: 0.0000e+00 - mae: 0.0101 - mse: 1.9001e-04 - val_loss: 2.2287e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0107 - val_mse: 2.2287e-04
# Epoch 63/100
# 29/29 [==============================] - 3s 105ms/step - loss: 1.9790e-04 - accuracy: 0.0000e+00 - mae: 0.0103 - mse: 1.9790e-04 - val_loss: 2.2964e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0107 - val_mse: 2.2964e-04
# Epoch 64/100
# 29/29 [==============================] - 3s 106ms/step - loss: 1.8311e-04 - accuracy: 0.0000e+00 - mae: 0.0099 - mse: 1.8311e-04 - val_loss: 2.3932e-04 - val_accuracy: 0.0000e+00 - val_mae: 0.0110 - val_mse: 2.3932e-04

# %% [markdown]
# ### Benchmark the model

# %%
# Use the stats stored in the history object.
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  accuracy       mae       mse  val_loss  val_accuracy   val_mae  \
# 59  0.000201       0.0  0.010373  0.000201  0.000283           0.0  0.012509
# 60  0.000199       0.0  0.010386  0.000199  0.000229           0.0  0.010787
# 61  0.000190       0.0  0.010128  0.000190  0.000223           0.0  0.010671
# 62  0.000198       0.0  0.010333  0.000198  0.000230           0.0  0.010726
# 63  0.000183       0.0  0.009937  0.000183  0.000239           0.0  0.010989
#
#      val_mse  epoch
# 59  0.000283     59
# 60  0.000229     60
# 61  0.000223     61
# 62  0.000230     62
# 63  0.000239     63

# %%
def plot_history(history, step=1):
    fig = plt.figure(figsize=(12, 3))
    hist = pd.DataFrame(history.history).iloc[::step]
    hist['epoch'] = history.epoch[::step]

    plt.subplot(131)
    plt.semilogy(hist['epoch'], hist['mae'], label='training')
    plt.semilogy(hist['epoch'], hist['val_mae'], label='test', alpha=0.8)
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error (mae)')

    plt.subplot(132)
    plt.semilogy(hist['epoch'], hist['mse'], label='training')
    plt.semilogy(hist['epoch'], hist['val_mse'], label='test', alpha=0.8)
    plt.legend()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Square Error (mse)')

    plt.tight_layout()


plot_history(history)

# %%
# Compute the overall scores of the model
scores = model.evaluate(test_data, test_labels, verbose=1)
# Out:
# 2/2 [==============================] - 0s 14ms/step - loss: 2.1877e-04 - accuracy: 0.0000e+00 - mae: 0.0106 - mse: 2.1877e-04

# %%
test_predictions = model.predict(test_data)

# %%
# compare truth and prediction for one or more test samples
for itest in range(1):
    plt.figure(figsize=(10, 4))
    plt.subplot(121)
    plt.imshow(test_labels[itest, ..., 0])
    plt.colorbar()
    plt.subplot(122)
    plt.imshow(test_predictions[itest, ..., 0])
    plt.colorbar()
    plt.suptitle('Normalized label values: truth vs. prediction')

# %%
# do the 45-degree plot; close to the diagonal == good
plt.plot((-1, 1), (-1, 1), c='r')
plt.scatter(test_labels.ravel(), test_predictions.ravel(), alpha=0.3)
plt.xlabel('truth')
plt.ylabel('predictions')
plt.title('Normalized label values')
plt.axis('equal')
# Out:
# (-1.1, 1.1, -1.1, 1.1)

# %% [markdown]
# ### Save the model

# %%
model_filename = 'closure-2d-model-qxxy.h5'
model.save(model_filename)

# %%
import h5py

model_file = h5py.File(model_filename, 'r')


def print_obj(name, obj):
    info = ''
    if isinstance(obj, h5py._hl.dataset.Dataset):
        info = str(obj.shape)
    print('{:42s} {:10s} {}'.format(name, info, type(obj)))


model_file.visititems(print_obj)

model_file.close()
# Out:
# model_weights                                         <class 'h5py._hl.group.Group'>
# model_weights/conv2d                                  <class 'h5py._hl.group.Group'>
# model_weights/conv2d/conv2d                           <class 'h5py._hl.group.Group'>
# model_weights/conv2d/conv2d/bias:0         (48,)      <class 'h5py._hl.dataset.Dataset'>
# model_weights/conv2d/conv2d/kernel:0       (16, 16, 2, 48) <class 'h5py._hl.dataset.Dataset'>
# model_weights/conv2d_1                                <class 'h5py._hl.group.Group'>
# model_weights/conv2d_1/conv2d_1                       <class 'h5py._hl.group.Group'>
# model_weights/conv2d_1/conv2d_1/bias:0     (48,)      <class 'h5py._hl.dataset.Dataset'>
# model_weights/conv2d_1/conv2d_1/kernel:0   (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# model_weights/conv2d_2                                <class 'h5py._hl.group.Group'>
# model_weights/conv2d_2/conv2d_2                       <class 'h5py._hl.group.Group'>
# model_weights/conv2d_2/conv2d_2/bias:0     (48,)      <class 'h5py._hl.dataset.Dataset'>
# model_weights/conv2d_2/conv2d_2/kernel:0   (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# model_weights/conv2d_3                                <class 'h5py._hl.group.Group'>
# model_weights/conv2d_3/conv2d_3                       <class 'h5py._hl.group.Group'>
# model_weights/conv2d_3/conv2d_3/bias:0     (48,)      <class 'h5py._hl.dataset.Dataset'>
# model_weights/conv2d_3/conv2d_3/kernel:0   (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# model_weights/conv2d_4                                <class 'h5py._hl.group.Group'>
# model_weights/conv2d_4/conv2d_4                       <class 'h5py._hl.group.Group'>
# model_weights/conv2d_4/conv2d_4/bias:0     (48,)      <class 'h5py._hl.dataset.Dataset'>
# model_weights/conv2d_4/conv2d_4/kernel:0   (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# model_weights/conv2d_5                                <class 'h5py._hl.group.Group'>
# model_weights/conv2d_5/conv2d_5                       <class 'h5py._hl.group.Group'>
# model_weights/conv2d_5/conv2d_5/bias:0     (1,)       <class 'h5py._hl.dataset.Dataset'>
# model_weights/conv2d_5/conv2d_5/kernel:0   (1, 1, 48, 1) <class 'h5py._hl.dataset.Dataset'>
# model_weights/max_pooling2d                           <class 'h5py._hl.group.Group'>
# model_weights/max_pooling2d_1                         <class 'h5py._hl.group.Group'>
# model_weights/up_sampling2d                           <class 'h5py._hl.group.Group'>
# model_weights/up_sampling2d_1                         <class 'h5py._hl.group.Group'>
# optimizer_weights                                     <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam                                <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d                         <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d/bias                    <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d/bias/m:0     (48,)      <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d/bias/v:0     (48,)      <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d/kernel                  <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d/kernel/m:0   (16, 16, 2, 48) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d/kernel/v:0   (16, 16, 2, 48) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_1                       <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_1/bias                  <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_1/bias/m:0   (48,)      <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_1/bias/v:0   (48,)      <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_1/kernel                <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_1/kernel/m:0 (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_1/kernel/v:0 (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_2                       <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_2/bias                  <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_2/bias/m:0   (48,)      <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_2/bias/v:0   (48,)      <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_2/kernel                <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_2/kernel/m:0 (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_2/kernel/v:0 (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_3                       <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_3/bias                  <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_3/bias/m:0   (48,)      <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_3/bias/v:0   (48,)      <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_3/kernel                <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_3/kernel/m:0 (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_3/kernel/v:0 (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_4                       <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_4/bias                  <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_4/bias/m:0   (48,)      <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_4/bias/v:0   (48,)      <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_4/kernel                <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_4/kernel/m:0 (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_4/kernel/v:0 (16, 16, 48, 48) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_5                       <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_5/bias                  <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_5/bias/m:0   (1,)       <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_5/bias/v:0   (1,)       <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_5/kernel                <class 'h5py._hl.group.Group'>
# optimizer_weights/Adam/conv2d_5/kernel/m:0 (1, 1, 48, 1) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/conv2d_5/kernel/v:0 (1, 1, 48, 1) <class 'h5py._hl.dataset.Dataset'>
# optimizer_weights/Adam/iter:0              ()         <class 'h5py._hl.dataset.Dataset'>
